# %%
import os
import argparse
import sys
import time
from math import ceil

import cv2
import numpy as np
import torch

from blink_utils.models.face_detectors import *

# %%
def latency_time(model_face_detector):
    timeFace = 0
    inference_times = np.array([])

    ContainerPath = './DataSet_imgs'
    listdir = os.listdir(ContainerPath)
    for SubContainer_path in listdir:
        SubContainer_path = os.path.join(ContainerPath, SubContainer_path)
        listdir_2 = os.listdir( SubContainer_path)
        for file_path in listdir_2: 
            startFaceDetector = time.time()
            #parsing the path of img
            img_path = os.path.join(SubContainer_path, file_path)
            image_ori = cv2.imread(img_path)
            #cv2.imshow(img_path,image_ori)
            facePoints = model_face_detector(image_ori)
            if facePoints == None:
                inference_times = np.append(inference_times,[[np.nan()]])
            else: inference_times = np.append(inference_times,[[time.time() - startFaceDetector]])
        

        
        
    return inference_times

# %%
faceDetector = HoGDlib('./modelFiles')
latency_time(faceDetector)
# Out:
# array([0.05498862, 0.05393672, 0.05186105, 0.05124927, 0.05112457,
#        0.05189919, 0.05209327, 0.05086875, 0.06185126, 0.05207109,
#        0.05186152, 0.05285859, 0.07380342, 0.05689573, 0.05185342,
#        0.05244493, 0.05038214, 0.05585265, 0.05112052, 0.05190253,
#        0.05631685, 0.05983925, 0.05086398, 0.05285978, 0.05290222,
#        0.05085325, 0.05185843, 0.05088258, 0.05084491, 0.05087996,
#        0.0508399 , 0.05186963, 0.05187368, 0.05085278, 0.05187178,
#        0.05186009, 0.0528636 , 0.05184698, 0.05190587, 0.05186152,
#        0.05184984, 0.05387592, 0.05184031, 0.05282474, 0.06291747,
#        0.06097889, 0.0532105 , 0.05285549, 0.05203986, 0.05202198,
#        0.05198359, 0.05183148, 0.05188131, 0.05129313, 0.05102563,
#        0.05298066, 0.05196905, 0.05124259, 0.05181646, 0.0519743 ,
#        0.05394483, 0.05099511, 0.05188894, 0.05116248, 0.05196643,
#        0.05431008, 0.05190992, 0.05683947, 0.05228281, 0.05286002,
#        0.05186176, 0.05191231, 0.05089927, 0.05285859, 0.05386543,
#        0.05142951, 0.04997039, 0.05176878, 0.05130386, 0.05198812,
#        0.051965  , 0.0511198 , 0.05481315, 0.05119705, 0.05083251,
#        0.05101895, 0.05194139, 0.05186653, 0.06134939, 0.05485129,
#        0.05485344, 0.05412698, 0.05238986, 0.0508635 , 0.05186105,
#        0.0518744 , 0.05122352, 0.05086374, 0.0518775 , 0.05320048])

# %%
ContainerPath = './DataSet_imgs'
listdir = os.listdir(ContainerPath)
for SubContainer_path in listdir:
    SubContainer_path = os.path.join(ContainerPath, SubContainer_path)
    listdir_2 = os.listdir( SubContainer_path)
    for file_path in listdir_2: 
        startFaceDetector = time.time()
        #parsing the path of img
        img_path = os.path.join(SubContainer_path, file_path)
        print(img_path)
# Out:
# ./DataSet_imgs\01\1.jpg
# ./DataSet_imgs\01\10.jpg
# ./DataSet_imgs\01\2.jpg
# ./DataSet_imgs\01\3.jpg
# ./DataSet_imgs\01\4.jpg
# ./DataSet_imgs\01\5.jpg
# ./DataSet_imgs\01\6.jpg
# ./DataSet_imgs\01\7.jpg
# ./DataSet_imgs\01\8.jpg
# ./DataSet_imgs\01\9.jpg
# ./DataSet_imgs\02\1.jpg
# ./DataSet_imgs\02\10.jpg
# ./DataSet_imgs\02\2.jpg
# ./DataSet_imgs\02\3.jpg
# ./DataSet_imgs\02\4.jpg
